# %% [markdown]
# | Triac | Resistor (Ω) |
# | ----- | ------------ |
# | T0    | 307 MΩ       |
# | T1    | 153 MΩ       |
# | T2    | 76.8 MΩ      |
# | T3    | 38.4 MΩ      |
# | T4    | 19.2 MΩ      |
# | T5    | 9.6 MΩ       |
# | T6    | 4.8 MΩ       |
# | T7    | 2.4 MΩ       |
# | T8    | 1.2 MΩ       |
# | T9    | 600 kΩ       |
# | T10   | 300 kΩ       |
# | T11   | 150 kΩ       |

# %%
300e6/120/3600
# Out:
# 694.4444444444445

# %%
3.4/680
# Out:
# 0.005
